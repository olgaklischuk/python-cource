# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('covid_19_data.csv')

# %%
df.head(10)
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
# 5    6      01/22/2020      Guangdong  Mainland China  1/22/2020 17:00
# 6    7      01/22/2020        Guangxi  Mainland China  1/22/2020 17:00
# 7    8      01/22/2020        Guizhou  Mainland China  1/22/2020 17:00
# 8    9      01/22/2020         Hainan  Mainland China  1/22/2020 17:00
# 9   10      01/22/2020          Hebei  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0
# 5       26.0     0.0        0.0
# 6        2.0     0.0        0.0
# 7        1.0     0.0        0.0
# 8        4.0     0.0        0.0
# 9        1.0     0.0        0.0

# %%
df.drop(['SNo','Last Update'],axis=1,inplace=True)
df.rename(columns={'ObservationDate':'Date','Province/State':'State','Country/Region':'Country'},inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
print(df.head(10))
# Out:
#         Date      State         Country  Confirmed  Deaths  Recovered
# 0 2020-01-22      Anhui  Mainland China        1.0     0.0        0.0
# 1 2020-01-22    Beijing  Mainland China       14.0     0.0        0.0
# 2 2020-01-22  Chongqing  Mainland China        6.0     0.0        0.0
# 3 2020-01-22     Fujian  Mainland China        1.0     0.0        0.0
# 4 2020-01-22      Gansu  Mainland China        0.0     0.0        0.0
# 5 2020-01-22  Guangdong  Mainland China       26.0     0.0        0.0
# 6 2020-01-22    Guangxi  Mainland China        2.0     0.0        0.0
# 7 2020-01-22    Guizhou  Mainland China        1.0     0.0        0.0
# 8 2020-01-22     Hainan  Mainland China        4.0     0.0        0.0
# 9 2020-01-22      Hebei  Mainland China        1.0     0.0        0.0

# %%
SimpleImputer?
# Out:
# Init signature:
# SimpleImputer(
#     *,
#     missing_values=nan,
#     strategy='mean',
#     fill_value=None,
#     verbose=0,
#     copy=True,
#     add_indicator=False,
# )
# Docstring:
# Imputation transformer for completing missing values.
#
# Read more in the :ref:`User Guide <impute>`.
#
# .. versionadded:: 0.20
#    `SimpleImputer` replaces the previous `sklearn.preprocessing.Imputer`
#    estimator which is now removed.
#
# Parameters
# ----------
# missing_values : int, float, str, np.nan or None, default=np.nan
#     The placeholder for the missing values. All occurrences of
#     `missing_values` will be imputed. For pandas' dataframes with
#     nullable integer dtypes with missing values, `missing_values`
#     should be set to `np.nan`, since `pd.NA` will be converted to `np.nan`.
#
# strategy : string, default='mean'
#     The imputation strategy.
#
#     - If "mean", then replace missing values using the mean along
#       each column. Can only be used with numeric data.
#     - If "median", then replace missing values using the median along
#       each column. Can only be used with numeric data.
#     - If "most_frequent", then replace missing using the most frequent
#       value along each column. Can be used with strings or numeric data.
#       If there is more than one such value, only the smallest is returned.
#     - If "constant", then replace missing values with fill_value. Can be
#       used with strings or numeric data.
#
#     .. versionadded:: 0.20
#        strategy="constant" for fixed value imputation.
#
# fill_value : string or numerical value, default=None
#     When strategy == "constant", fill_value is used to replace all
#     occurrences of missing_values.
#     If left to the default, fill_value will be 0 when imputing numerical
#     data and "missing_value" for strings or object data types.
#
# verbose : integer, default=0
#     Controls the verbosity of the imputer.
#
# copy : boolean, default=True
#     If True, a copy of X will be created. If False, imputation will
#     be done in-place whenever possible. Note that, in the following cases,
#     a new copy will always be made, even if `copy=False`:
#
#     - If X is not an array of floating values;
#     - If X is encoded as a CSR matrix;
#     - If add_indicator=True.
#
# add_indicator : boolean, default=False
#     If True, a :class:`MissingIndicator` transform will stack onto output
#     of the imputer's transform. This allows a predictive estimator
#     to account for missingness despite imputation. If a feature has no
#     missing values at fit/train time, the feature won't appear on
#     the missing indicator even if there are missing values at
#     transform/test time.
#
# Attributes
# ----------
# statistics_ : array of shape (n_features,)
#     The imputation fill value for each feature.
#     Computing statistics can result in `np.nan` values.
#     During :meth:`transform`, features corresponding to `np.nan`
#     statistics will be discarded.
#
# indicator_ : :class:`~sklearn.impute.MissingIndicator`
#     Indicator used to add binary indicators for missing values.
#     ``None`` if add_indicator is False.
#
# See Also
# --------
# IterativeImputer : Multivariate imputation of missing values.
#
# Examples
# --------
# >>> import numpy as np
# >>> from sklearn.impute import SimpleImputer
# >>> imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
# >>> imp_mean.fit([[7, 2, 3], [4, np.nan, 6], [10, 5, 9]])
# SimpleImputer()
# >>> X = [[np.nan, 2, 3], [4, np.nan, 6], [10, np.nan, 9]]
# >>> print(imp_mean.transform(X))
# [[ 7.   2.   3. ]
#  [ 4.   3.5  6. ]
#  [10.   3.5  9. ]]
#
# Notes
# -----
# Columns which only contained missing values at :meth:`fit` are discarded
# upon :meth:`transform` if strategy is not "constant".
# File:           /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/impute/_base.py
# Type:           type
# Subclasses:

# %%
imputer = SimpleImputer(strategy='constant')# fill Na by 'missing value'
df2 = pd.DataFrame(imputer.fit_transform(df),columns=df.columns)
df2.head(50)
# Out:
#          Date           State         Country Confirmed Deaths Recovered
# 0  2020-01-22           Anhui  Mainland China         1      0         0
# 1  2020-01-22         Beijing  Mainland China        14      0         0
# 2  2020-01-22       Chongqing  Mainland China         6      0         0
# 3  2020-01-22          Fujian  Mainland China         1      0         0
# 4  2020-01-22           Gansu  Mainland China         0      0         0
# 5  2020-01-22       Guangdong  Mainland China        26      0         0
# 6  2020-01-22         Guangxi  Mainland China         2      0         0
# 7  2020-01-22         Guizhou  Mainland China         1      0         0
# 8  2020-01-22          Hainan  Mainland China         4      0         0
# 9  2020-01-22           Hebei  Mainland China         1      0         0
# 10 2020-01-22    Heilongjiang  Mainland China         0      0         0
# 11 2020-01-22           Henan  Mainland China         5      0         0
# 12 2020-01-22       Hong Kong       Hong Kong         0      0         0
# 13 2020-01-22           Hubei  Mainland China       444     17        28
# 14 2020-01-22           Hunan  Mainland China         4      0         0
# 15 2020-01-22  Inner Mongolia  Mainland China         0      0         0
# 16 2020-01-22         Jiangsu  Mainland China         1      0         0
# 17 2020-01-22         Jiangxi  Mainland China         2      0         0
# 18 2020-01-22           Jilin  Mainland China         0      0         0
# 19 2020-01-22        Liaoning  Mainland China         2      0         0
# 20 2020-01-22           Macau           Macau         1      0         0
# 21 2020-01-22         Ningxia  Mainland China         1      0         0
# 22 2020-01-22         Qinghai  Mainland China         0      0         0
# 23 2020-01-22         Shaanxi  Mainland China         0      0         0
# 24 2020-01-22        Shandong  Mainland China         2      0         0
# 25 2020-01-22        Shanghai  Mainland China         9      0         0
# 26 2020-01-22          Shanxi  Mainland China         1      0         0
# 27 2020-01-22         Sichuan  Mainland China         5      0         0
# 28 2020-01-22          Taiwan          Taiwan         1      0         0
# 29 2020-01-22         Tianjin  Mainland China         4      0         0
# 30 2020-01-22           Tibet  Mainland China         0      0         0
# 31 2020-01-22      Washington              US         1      0         0
# 32 2020-01-22        Xinjiang  Mainland China         0      0         0
# 33 2020-01-22          Yunnan  Mainland China         1      0         0
# 34 2020-01-22        Zhejiang  Mainland China        10      0         0
# 35 2020-01-22   missing_value           Japan         2      0         0
# 36 2020-01-22   missing_value        Thailand         4      0         2
# 37 2020-01-22   missing_value     South Korea         1      0         0
# 38 2020-01-22         Unknown           China         0      0         0
# 39 2020-01-22   missing_value        Kiribati         0      0         0
# 40 2020-01-23           Anhui  Mainland China         9      0         0
# 41 2020-01-23         Beijing  Mainland China        22      0         0
# 42 2020-01-23       Chongqing  Mainland China         9      0         0
# 43 2020-01-23          Fujian  Mainland China         5      0         0
# 44 2020-01-23           Gansu  Mainland China         2      0         0
# 45 2020-01-23       Guangdong  Mainland China        32      0         2
# 46 2020-01-23         Guangxi  Mainland China         5      0         0
# 47 2020-01-23         Guizhou  Mainland China         3      0         0
# 48 2020-01-23          Hainan  Mainland China         5      0         0
# 49 2020-01-23           Hubei  Mainland China       444     17        28

# %%
df3 = df2.groupby(['Country','Date'])[['Country','Date','Confirmed','Deaths','Recovered']].sum().reset_index()

# %%
df3.head(20)
# Out:
#             Country       Date  Confirmed  Deaths  Recovered
# 0        Azerbaijan 2020-02-28        1.0     0.0        0.0
# 1   ('St. Martin',) 2020-03-10        2.0     0.0        0.0
# 2       Afghanistan 2020-02-24        1.0     0.0        0.0
# 3       Afghanistan 2020-02-25        1.0     0.0        0.0
# 4       Afghanistan 2020-02-26        1.0     0.0        0.0
# 5       Afghanistan 2020-02-27        1.0     0.0        0.0
# 6       Afghanistan 2020-02-28        1.0     0.0        0.0
# 7       Afghanistan 2020-02-29        1.0     0.0        0.0
# 8       Afghanistan 2020-03-01        1.0     0.0        0.0
# 9       Afghanistan 2020-03-02        1.0     0.0        0.0
# 10      Afghanistan 2020-03-03        2.0     0.0        0.0
# 11      Afghanistan 2020-03-04        4.0     0.0        0.0
# 12      Afghanistan 2020-03-05        4.0     0.0        0.0
# 13      Afghanistan 2020-03-06        4.0     0.0        0.0
# 14      Afghanistan 2020-03-07        4.0     0.0        0.0
# 15      Afghanistan 2020-03-08        5.0     0.0        0.0
# 16      Afghanistan 2020-03-09        7.0     0.0        0.0
# 17      Afghanistan 2020-03-10        8.0     0.0        0.0
# 18      Afghanistan 2020-03-11       11.0     0.0        0.0
# 19      Afghanistan 2020-03-12       12.0     0.0        0.0

# %%
countries = df3['Country'].unique()
len(countries)

# %%
df3[df3['Country']=='Ukraine'].reset_index()
# Out:
#      index  Country       Date  Confirmed   Deaths  Recovered
# 0    82592  Ukraine 2020-03-03        1.0      0.0        0.0
# 1    82593  Ukraine 2020-03-04        1.0      0.0        0.0
# 2    82594  Ukraine 2020-03-05        1.0      0.0        0.0
# 3    82595  Ukraine 2020-03-06        1.0      0.0        0.0
# 4    82596  Ukraine 2020-03-07        1.0      0.0        0.0
# ..     ...      ...        ...        ...      ...        ...
# 448  83040  Ukraine 2021-05-25  2244084.0  51682.0  2028598.0
# 449  83041  Ukraine 2021-05-26  2247605.0  51898.0  2043720.0
# 450  83042  Ukraine 2021-05-27  2251242.0  52088.0  2060753.0
# 451  83043  Ukraine 2021-05-28  2254674.0  52252.0  2074174.0
# 452  83044  Ukraine 2021-05-29  2257904.0  52414.0  2084477.0
#
# [453 rows x 6 columns]

# %%
Country=[]
if input(Country) == 'Ukraine':
        C = df3[df3['Country']=='Ukraine'].reset_index()        
        plt.scatter(np.arange(0,len(C)),C['Confirmed'],color='blue',label='Confirmed')
        plt.scatter(np.arange(0,len(C)),C['Recovered'],color='green',label='Recovered')
        plt.scatter(np.arange(0,len(C)),C['Deaths'],color='red',label='Deaths')
        plt.title(countries[df3['Country'].unique()=='Ukraine'])
        plt.xlabel('Days since the first suspect')
        plt.ylabel('Number of cases')
        plt.legend()
        plt.show()  
else:
    for idx in range(0,len(countries)):    
        C = df3[df3['Country']==countries[idx]].reset_index()        
        plt.scatter(np.arange(0,len(C)),C['Confirmed'],color='blue',label='Confirmed')
        plt.scatter(np.arange(0,len(C)),C['Recovered'],color='green',label='Recovered')
        plt.scatter(np.arange(0,len(C)),C['Deaths'],color='red',label='Deaths')
        plt.title(countries[idx])
        plt.xlabel('Days since the first suspect')
        plt.ylabel('Number of cases')
        plt.legend()
        plt.show()
# Out:
# [] Ukraine

# %%
C = df3[df3['Country']=='Ukraine'].reset_index()
C[['Country','Date','Confirmed','Recovered','Deaths']]
# Out:
#      Country       Date  Confirmed  Recovered   Deaths
# 0    Ukraine 2020-03-03        1.0        0.0      0.0
# 1    Ukraine 2020-03-04        1.0        0.0      0.0
# 2    Ukraine 2020-03-05        1.0        0.0      0.0
# 3    Ukraine 2020-03-06        1.0        0.0      0.0
# 4    Ukraine 2020-03-07        1.0        0.0      0.0
# ..       ...        ...        ...        ...      ...
# 448  Ukraine 2021-05-25  2244084.0  2028598.0  51682.0
# 449  Ukraine 2021-05-26  2247605.0  2043720.0  51898.0
# 450  Ukraine 2021-05-27  2251242.0  2060753.0  52088.0
# 451  Ukraine 2021-05-28  2254674.0  2074174.0  52252.0
# 452  Ukraine 2021-05-29  2257904.0  2084477.0  52414.0
#
# [453 rows x 5 columns]

# %%
df4 = df3.groupby(['Date'])[['Date','Confirmed','Deaths','Recovered']].sum().reset_index()

# %%
C = df4
plt.scatter(np.arange(0,len(C)),C['Confirmed'],color='blue',label='Confirmed')
plt.scatter(np.arange(0,len(C)),C['Recovered'],color='green',label='Recovered')
plt.scatter(np.arange(0,len(C)),C['Deaths'],color='red',label='Deaths')
plt.title('World')
plt.xlabel('Days since the first suspect')
plt.ylabel('Number of cases')
plt.legend()
plt.show()
