# %%
#!/usr/bin/env python
# coding: utf-8

# %% [markdown]
# #### **1. Import all the required libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### **2. Import the supermarket sales data excel file**

# %%
mart = pd.read_excel(r'supermarket_sales.xlsx', engine= 'openpyxl')
mart.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
#        Payment    cogs  gross margin percentage  gross income  Rating
# 0  Credit card  164.52                 4.761905         8.226     5.9
# 1      Ewallet   57.92                 4.761905         2.896     4.5
# 2         Cash  102.04                 4.761905         5.102     6.8
# 3         Cash  562.32                 4.761905        28.116     4.5
# 4      Ewallet   80.60                 4.761905         4.030     4.4

# %% [markdown]
# #### **3. Create a basic SWARM PLOT on Total column**

# %%
sns.swarmplot(data=mart,y='Total')

# %% [markdown]
# #### **4. Create SWARM PLOT group by CATEGORIES**

# %%
sns.swarmplot(data=mart,y='Total',x='Payment',hue='Gender')

# %% [markdown]
# #### **5. Showing Hues Separatly on the categorical axis**

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(data=mart,y='Total',x='Payment',hue='Gender',split=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_183/1382784393.py in <module>
#       1 plt.figure(figsize=(15,5))
# ----> 2 sns.swarmplot(data=mart,y='Total',x='Payment',hue='Gender',split=True)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/categorical.py in swarmplot(data, x, y, hue, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, native_scale, formatter, legend, warn_thresh, ax, **kwargs)
#    2667         edgecolor=edgecolor,
#    2668         warn_thresh=warn_thresh,
# -> 2669         plot_kws=kwargs,
#    2670     )
#    2671
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/categorical.py in plot_swarms(self, dodge, color, edgecolor, warn_thresh, plot_kws)
#     354
#     355             ax = self._get_axes(sub_vars)
# --> 356             points = ax.scatter(sub_data["x"], sub_data["y"], color=color, **plot_kws)
#     357
#     358             if "hue" in self.variables:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4441                 )
#    4442         collection.set_transform(mtransforms.IdentityTransform())
# -> 4443         collection.update(kwargs)
#    4444
#    4445         if colors is None:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#    1000                 if not callable(func):
#    1001                     raise AttributeError('{!r} object has no property {!r}'
# -> 1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#    1004
#
# AttributeError: 'PathCollection' object has no property 'split'

# %% [markdown]
# #### **6. Styling a SWARM - Change the marker, size, color, edge color.....**

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(data=mart,y='Total',x='Payment',size=10,color='green',edgecolor='black')
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/categorical.py:3544: UserWarning: 13.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/categorical.py:3544: UserWarning: 13.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/categorical.py:3544: UserWarning: 12.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### **7. Overlay a SWARM PLOT on a BOX PLOT**

# %%
sns.boxplot(data=mart,y='Total',x='Payment')
sns.swarmplot(data=mart,y='Total',x='Payment',color='black')

# %% [markdown]
# #### **8. Overlay a SWARM PLOT on a VIOLIN PLOT**

# %%
sns.violinplot(data=mart,y='Total',x='Payment',inner=None,width=1)
sns.swarmplot(data=mart,y='Total',x='Payment',color='white')
